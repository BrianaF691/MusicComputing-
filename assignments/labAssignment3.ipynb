# %% [markdown]
# <a href="https://colab.research.google.com/github/BrianaF691/MusicComputing-/blob/main/assignments/labAssignment3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pylab as plt
import librosa.display
import IPython.display
import librosa

#import audio files
# !git clone https://github.com/jcdevaney/musicComputing2025.git
# Out:
# Cloning into 'musicComputing2025'...
# remote: Enumerating objects: 125, done.
# remote: Counting objects: 100% (125/125), done.
# remote: Compressing objects: 100% (113/113), done.
# remote: Total 125 (delta 56), reused 18 (delta 5), pack-reused 0 (from 0)
# Receiving objects: 100% (125/125), 17.83 MiB | 10.85 MiB/s, done.
# Resolving deltas: 100% (56/56), done.

# %%
def plotAudio2(sig,sampleRate,title):


   # this version expects the audio file to have already been opened by librosa


   # Adjust the x-axis to represent time


   time=np.arange(0,sig.shape[0])/sr


   # Scale the y-axis to represent amplitude from -1 to 1
   excursion=max(abs(sig))
   sigNew = sig / excursion


   # Label the x and y axes with variables
   xlabel = 'Time (seconds)'
   ylabel = 'Amplitude'


   #plot the signal using the x and y axis variables
   plt.plot(time,sigNew)
   plt.xlabel(xlabel)
   plt.ylabel(ylabel)
   plt.title(title)
   plt.show()

# %%
def plotAudioFreqDomain(sig,sr,title,winSize,specType):

    # create a normalized spectrogram
    # this includes several function calls
    # first create a basic specgrogram with librosa.stft() with the default window size (2048)
    spec = librosa.stft(sig,n_fft=winSize)
    # then make all of values in the spectrogram positive with np.abs()
    spec = np.abs(spec)
    # then scale the spectogram to be in decibels, so it better reflects how we hear librosa.amplitude_to_db()
    spec = librosa.amplitude_to_db(np.abs(librosa.stft(sig,n_fft=winSize)),ref=np.max)
    # display the normalized spectrogram with a log frequency scale
    plt.figure()
    librosa.display.specshow(spec,y_axis= specType)
    specType = 'log'
    specType = 'linear'
    plt.title(title)
    plt.colorbar(format='%+2.0f dB')

# %%
def plotAudioFunc(sig,sr,title,winSize,specType):

    #call plotAudio2
    plotAudio2(sig,sr,title)
    #call plotAudioFreqDomain
    plotAudioFreqDomain(sig,sr,title,winSize,specType)

# %%
sig , sr = librosa.load('musicComputing2025/audioFiles/avm.wav')

# %%
title = 'Ave Maria'
winSize = 2048
specType = 'linear'

#call plotAudioFunc
plotAudioFunc(sig,sr,'Ave Maria',2048,'linear')

# %%
title = 'Ave Maria'
winSize = 2048
specType = 'log'

#call plotAudioFunc
plotAudioFunc(sig,sr,'Ave Maria',2048,'log')

# %%
title = 'Ave Maria'
winSize = 256
specType = 'linear'

#call plotAudioFunc
plotAudioFunc(sig,sr,'Ave Maria',256,'linear')

# %%
title = 'Ave Maria'
winSize = 256
specType = 'log'

# call plotAudioFunc
plotAudioFunc(sig,sr,'Ave Maria',256,'log')
